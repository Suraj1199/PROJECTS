# %% [markdown]
# # Exercise - List

# %% [markdown]
# 1) Create  any random list and assign it to a variable dummy_list

# %%
rand_list = [7,11.11,19,11]
dummy_list = rand_list

# %% [markdown]
# 2) print dummy_list

# %%
print (dummy_list)
# Out:
# [7, 11.11, 19, 11]

# %% [markdown]
# 3) Reverse dummy_list and print

# %%
dummy_list.reverse()

print (dummy_list)
# Out:
# [11, 19, 11.11, 7]

# %% [markdown]
# 4) Add the list dummy_list_2 to the previous dummy_list and now print dummy_list

# %%
dummy_list_2 = [2, 200, 16, 4, 1, 0, 9.45, 45.67, 90, 12.01, 12.02]

for i in dummy_list_2:
    dummy_list.append(i)

print(dummy_list)
# Out:
# [11, 19, 11.11, 7, 2, 200, 16, 4, 1, 0, 9.45, 45.67, 90, 12.01, 12.02]

# %% [markdown]
# 5) Create a dictionary named dummy_dict which contains all the elements of dummy_list as keys and frequency as values.

# %% [markdown]
# 6) print dummy_dict

# %% [markdown]
# 7) Sort dummy_list in ascending order as well as descending order and print the changed lists

# %%
print (dummy_list)

print(sorted(dummy_list))

print(sorted(dummy_list,reverse=True))
# Out:
# [11, 19, 11.11, 7, 2, 200, 16, 4, 1, 0, 9.45, 45.67, 90, 12.01, 12.02]
# [0, 1, 2, 4, 7, 9.45, 11, 11.11, 12.01, 12.02, 16, 19, 45.67, 90, 200]
# [200, 90, 45.67, 19, 16, 12.02, 12.01, 11.11, 11, 9.45, 7, 4, 2, 1, 0]

# %% [markdown]
# 8) Remove the first item from the list whose value is equal to x. It raises a ValueError if there is no such item.

# %%
x = 200
dummy_list.remove(x)
print(dummy_list)
# Let's play: try the same with something which is not in the list to get the ValueError,remove #

#x = 5
#dummy_list.remove(x)
#print(dummy_list)
# Out:
# [11, 19, 11.11, 7, 2, 16, 4, 1, 0, 9.45, 45.67, 90, 12.01, 12.02]

# %% [markdown]
# 9) Remove the item at position x. x is any random integer

# %%
dummy_list.pop(2)   #11.11 will be deleted
print(dummy_list)

# Let's play: try doing the same with x > len(dummy_list) + 1 and see what you get
#remove # and the following will give indexError

#dummy_list.pop(50)
# Out:
# [11, 19, 7, 2, 16, 4, 1, 0, 9.45, 45.67, 90, 12.01, 12.02]

# %% [markdown]
# 10) Let's clean everything clear the list and then print

# %%
dummy_list = []
print (dummy_list)
